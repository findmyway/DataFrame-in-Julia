# %% [markdown]
# # A quick tour of Jupyter Notebook
#
# The easest way to try Julia is to login [JuliaBox](https://juliabox.com/) and click the **Sync** tab to sync this repo into your own folder. If you would like to run everything on your local machine, [JuliaPro](https://juliacomputing.com/products/juliapro.html) is a good start. After installing JuliaPro, clone this repo and run `jupyter notebook` there. You'll see the notebooks opened in your default browser.
#
# If you have used jupyter notebook with a python kernel before, you would probably be familiar with the same way to run julia codes in a cell. My only advice is to forget about the indentation ;)
#
# One difference from IPython is the magic commands start with `%`. [IJulia](https://github.com/JuliaLang/IJulia.jl) will tell you the alternative way to achieve the same effect.

# %%
%paste
# Out:
# ```
# The analogue of `%paste` in IPython is `IJulia.load_string(clipboard())`
# in IJulia (to load code from the clipboard into the current frontend).
# ```

# %% [markdown]
# # Package Management
#
# Unlike Python which uses `pip` in the terminal to manage packages, Julia has a lot of functions for package management. The most useful functions are `Pkg.add`, `Pkg.status` and `Pkg.update()`. You can use the `?` to check how to use a function like bellow:

# %%
? Pkg.add
# Out:
# ```
# add(pkg, vers...)
# ```
#
# Add a requirement entry for `pkg` to `Pkg.dir("REQUIRE")` and call `Pkg.resolve()`. If `vers` are given, they must be `VersionNumber` objects and they specify acceptable version intervals for `pkg`.

# %% [markdown]
# Personally I often use [devdocs](https://github.com/Thibaut/devdocs) to search for functions.
#
# JuliaBox and JuliaPro have already installed many basic packages for you. You can check whether you have installed a package with `Pkg.status("Packagename")`. Notice that some packages need to run `Pkg.build` after `Pkg.add`(like the GPU related package). You can check the related documentation for details.

# %% [markdown]
# # Modules

# %% [markdown]
# Modules in Julia is very different from Python(more similar to F#?). In most Julia codes, we write `using XXX`(like `from XXX import *` in Python), and the `XXX` module will be used to resolve variable names. I strongly suggest you to go through the official [doc](https://docs.julialang.org/en/stable/manual/modules/). At first, you may be a little unconfortable to import modules in this way. However, you'll feel very convenient when you get used to it.

# %%
using Plots
plot([sin, cos], 0:0.1:π)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3400)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3400)" points="
# 39.1436,375.813 580.315,375.813 580.315,11.811 39.1436,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="11" width="542" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.1436,370.353 39.1436,17.2711
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   213.715,370.353 213.715,17.2711
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   388.286,370.353 388.286,17.2711
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   562.858,370.353 562.858,17.2711
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.2612,284.931 572.197,284.931
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.2612,193.891 572.197,193.891
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.2612,102.851 572.197,102.851
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.2612,11.811 572.197,11.811
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,375.813 39.1436,11.811
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,375.813 39.1436,370.353
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   213.715,375.813 213.715,370.353
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   388.286,375.813 388.286,370.353
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   562.858,375.813 562.858,370.353
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,284.931 47.2612,284.931
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,193.891 47.2612,193.891
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,102.851 47.2612,102.851
#   "/>
# <polyline clip-path="url(#clip3400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,11.811 47.2612,11.811
#   "/>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 39.1436, 389.613)" x="39.1436" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 213.715, 389.613)" x="213.715" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 388.286, 389.613)" x="388.286" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 562.858, 389.613)" x="562.858" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.1436, 289.431)" x="33.1436" y="289.431">-0.5</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.1436, 198.391)" x="33.1436" y="198.391">0.0</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.1436, 107.351)" x="33.1436" y="107.351">0.5</text>
# </g>
# <g clip-path="url(#clip3400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.1436, 16.311)" x="33.1436" y="16.311">1.0</text>
# </g>
# <polyline clip-path="url(#clip3402)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.1436,193.891 56.6007,175.713
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   56.6007,175.713 74.0579,157.717
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   74.0579,157.717 91.515,140.083
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   91.515,140.083 108.972,122.986
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   108.972,122.986 126.429,106.597
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   126.429,106.597 143.886,91.0809
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   143.886,91.0809 161.344,76.5918
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   161.344,76.5918 178.801,63.2748
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   178.801,63.2748 196.258,51.2628
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   196.258,51.2628 213.715,40.676
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   213.715,40.676 231.172,31.62
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   231.172,31.62 248.629,24.1853
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   248.629,24.1853 266.086,18.4463
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   266.086,18.4463 283.544,14.4603
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   283.544,14.4603 301.001,12.2671
#   "/>
# <polyline clip-path="url(#clip3402)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   301.001,12.2671 318.458,11.8887
#   "/>
# <polyline clip-path="url(#clip3402)" style=

# %% [markdown]
# As you have noticed, in Julia we can use unicode as variable names. In notebook, you can type `\pi[TAB]` to get `π`.
